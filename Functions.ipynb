# %%
# def greet():
#     print("Welcome to our app!")
# greet()  

# def name(username):
#     print("hello",username)
# name("Rohit")
# name("Ananya")



# a = 10
# b = 20
# sum = a+b 
# print(sum)


# a = 30
# b = 40
# sum = a+b
# print(sum)


# a = 50
# b = 60
# sum = a+b
# print(sum)



# def calculate_sum(a,b,c):
#     sum = a+b+c
#     print(sum)
# calculate_sum(10,20,30)
# calculate_sum(30,40,50)
# calculate_sum(50,60,60)


# def calculate_sum(a,b):
#     return a+b
# sum = calculate_sum(1,2)
# sum1 = calculate_sum(2,3)
# print(sum)
# print(sum1)


# function call without passing parameter:

# def hello_world():
#     print("Hello")
# hello_world()
# hello_world()


# def average(a,b,c):
#     average1 = (a+b+c)/3
#     print(average1)
# average(1,2,3)

# default parameteres:
# def prod(a=1,b=2):
#     print(a*b)
# prod()


# def greet(name,age):
#     print(name,age)
# greet(age = 16,name = "rohit")


# def greet(name,age):
#     print(name,age)
# greet(15,"Rohit")


# def greet(name:str,age:int):
#     print(name,age)
# greet(15,"Rohit")


def greet(name, age=18):
    print(name,age)
greet("Aman")        # Uses default age=18
greet(19)   # Overrides default age
# Out:
# Aman 18
# 19 18

# %%
# def rectangle(length, width):
#     area = length * width
#     perimeter = 2 * (length + width)
#     return area, perimeter

# # taking input from user
# l = int(input("Enter the length of the rectangle: "))
# w = int(input("Enter the width of the rectangle: "))

# a, p = rectangle(l, w)
# print("Area:", a)
# print("Perimeter:", p)



# def rectangle(length,width):
#     area = length*width
#     perimeter = 2*(length+width)
#     return area,perimeter

# l = int(input("Enter the length of the rectangle"))
# w = int(input("enter the width of the rectangle"))

# a,p = rectangle(l,w)
# print("area",a)
# print("permiter",w)
# Out:
# area 6
# permiter 3

# %%
square = lambda x: x * x
print(square(4))


square = lambda x:x*x
print(square(4))
# Out:
# 16
# 16

# %%
# def add(a,b):
#     sum = a+b
#     print(sum)
# add(1,2)



# def add(a,b):
#     return a+b
# add(1,2)


# def square(a,b):
#     return a*b
# square(2,2)


# def rectangle_print(a,b):
#     area = a*b
#     perimeter = 2*(a+b)
#     return area,perimeter
# rectangle_print(1,2)

# def rectangle_print(*args):
#     area = args[0] * args[1]
#     perimeter = 2 * (args[0] + args[1])
#     return area, perimeter

# print(rectangle_print(5, 3))




# def factorial(n):
#     fact = 1
#     for i in range(1,n+1):
#         fact = fact*i
#     print(fact) 
# factorial(5)
# factorial(6)

# def rectangle_return(length, width):
#     area = length * width
#     perimeter = 2 * (length + width)
#     return area, perimeter

# a, p = rectangle_return(10, 5)
# print("Area:", a)
# print("Perimeter:", p)


# def marks_print(m1,m2,m3):
#     total = m1+m2+m3
#     average = total/3
#     print("average",average)
#     print("total",total)
# marks_print(1,2,3)


# def sum_of_cubes(num):
#     total = 0
#     while num>0:
#         digit = num%10
#         total += digit**3
#         num//=10
#     print(total)
# sum_of_cubes(123)
# Out:
# 36

# %%
# Function for addition
def add(a, b):
    return a + b
# Function for subtraction
def subtract(a, b):
    return a - b
# Function for multiplication
def multiply(a, b):
    return a * b
# Function for division
def divide(a, b):
    if b == 0:
        return "Error! Division by zero."
    return a / b
# Main program
print("Select operation:")
print("1. Add")
print("2. Subtract")
print("3. Multiply")
print("4. Divide")

choice = input("Enter choice (1/2/3/4): ")
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
if choice == '1':
    print("Result:", add(num1, num2))
elif choice == '2':
    print("Result:", subtract(num1, num2))
elif choice == '3':
    print("Result:", multiply(num1, num2))
elif choice == '4':
    print("Result:", divide(num1, num2))
else:
    print("Invalid choice")
# Out:
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# Result: 2.0

# %%
# functions:
# def greet():
#     print("Pranitha")
# greet()


# def greet():
#     print(1,2)
# greet()



# def add(a,b):
#     return a+b
# add(1,2)


def add(a,b):
    print(a+b)

def sub(a,b):
    print(a-b)

def mul(a,b):
    return a*b

print(mul(1,2))
sub(2,1)
add(1,2)
# Out:
# 2
# 1
# 3

# %%
y = 5
def my_func():
    y = 5
    print("Inside function:", y)
my_func()         
print(y)
# Out:
# Inside function: 5
# 5

# %%
# x = 10 
# def my_func():
#     x = 5  
#     print("Inside function:", x)
# my_func()
# print("Outside function:", x)

# %%
def count_vowels_print(text):
    vowels = "aeiouAEIOU"
    count = 0
    for ch in text:
        if ch in vowels:
            count += 1
    print("Number of vowels:", count)

count_vowels_print("Programming in Python")
# Out:
# Number of vowels: 5

# %%
# def greet():
#     print("hey how are u")
# greet()
# Out:
# hey how are u

# %%
# def greet(a,b):
#     print(1,2)
# greet(1,2)


# def sum(a,b):
#     print(a+b)
# sum(1,2)


# def sum(name,age):
#     print(name,age)
# sum("Rohit",15)

# def sum(name= "Rohit",age=19):
#     print(name,age)
# sum()


# def sum(name,age):
#     print(name,age)
# sum(age= 18,name="Rohit")


# Define the function
# def function(a, b):
#     area = a * b
#     perimeter = 2 * (a + b)
#     return area, perimeter

# # Take input from user
# a = int(input("Enter the value of a: "))
# b = int(input("Enter the value of b: "))
# # Call the function and get results
# area, perimeter = function(a, b)
# # Print nicely
# print("Area is:", area)
# print("Perimeter is:", perimeter)

def function(a,b):
    area = a*b
    perimeter = 2*(a+b)
    return area,perimeter
area,perimeter = function(1,2)
print("area is",area)
print("perimeter is",perimeter)
# Out:
# area is 2
# perimeter is 6
